# %%
# Author: Cameron Liu
# 
# Purpose: This file is dedicated to parsing all the information from a file, and putting the only things that I need in the file
#  I want to be able to import this function, and then be able to get all the information from this file because of it. 
#  The data structure that I will be using for this is probably a dictionary.
# 


# The key will be the sd of the file, and the value in the dictionary will probably be a tuple with all the information from the file as the value of the tuple.
# So, the format will be: 
# dict = {a: (x, y), b: (x, y)}
# Out:
# hello world
